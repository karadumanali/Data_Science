# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
veriler = pd.read_csv("athlete_events.csv")

# %%
veriler.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
print(veriler.columns,"\n")
print(veriler.isnull())
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')
#
#            ID   Name    Sex    Age  Height  Weight   Team    NOC  Games  \
# 0       False  False  False  False   False   False  False  False  False
# 1       False  False  False  False   False   False  False  False  False
# 2       False  False  False  False    True    True  False  False  False
# 3       False  False  False  False    True    True  False  False  False
# 4       False  False  False  False   False   False  False  False  False
# ...       ...    ...    ...    ...     ...     ...    ...    ...    ...
# 271111  False  False  False  False   False   False  False  False  False
# 271112  False  False  False  False   False   False  False  False  False
# 271113  False  False  False  False   False   False  False  False  False
# 271114  False  False  False  False   False   False  False  False  False
# ...

# %%
print(veriler.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB
# None

# %%
plt.scatter("Height","Weight",data=veriler)
plt.xlabel("uzunluk")
plt.ylabel("kilo")
plt.title("uzunluk-kilo")
plt.show()

# %%
sns.set_style("whitegrid") #gird:izgara, black, blackgird gibi secenekler vardir. -set_theme()-->default degerdir beyaz
sns.scatterplot(x="Height", y="Weight", data=veriler)
plt.xlabel("uzunluk")
plt.ylabel("kilo")
plt.title("uzunluk-kilo")
plt.show()

# %% [markdown]
# ##### daha guzel bir gorunum ortaya cikti matplotlib'e gore<br> biz tabi cinsiyete gore boy-kilo dagilimini da merak eedebiliriz demi

# %%
sns.set_style("darkgrid") #gird:izgara, black, blackgird gibi secenekler vardir. -set_theme()-->default degerdir beyaz
sns.scatterplot(x="Height", y="Weight",hue="Sex" ,data=veriler) #hue'ya neyi merak ediyorsak aydinlatmak istiyorsak verebilriiz.
plt.xlabel("uzunluk")
plt.ylabel("kilo")
plt.title("uzunluk-kilo")
plt.show()

# %% [markdown]
# #### goruldugu uzere label filan vererek ayrim yaptirabiliyor. Taabi ki hue'ya cok fazla kategorik degeri olmayan verirsek iyi olur

# %% [markdown]
# ## Seaborn grafik cesitleri

# %%
veriler.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
veriler["Medal"].unique() #bize o column'daki uniq degerler yani burdaki kategorileri verecektir
# Out:
# array([nan, 'Gold', 'Bronze', 'Silver'], dtype=object)

# %%
sns.set_style("whitegrid") #gird:izgara, black, blackgird gibi secenekler vardir. -set_theme()-->default degerdir beyaz
sns.scatterplot(x="Height", y="Weight", hue="Sex",style="Medal", data=veriler) #her birinin stilini medal'a gore degistir
plt.xlabel("uzunluk")
plt.ylabel("kilo")
plt.title("uzunluk-kilo")
plt.show()

# %% [markdown]
# ##### goruldugu uzere gold-m, gold-f gibi ayrimlar yapabiliyoruz

# %%
sns.set_style("whitegrid") #gird:izgara, black, blackgird gibi secenekler vardir. -set_theme()-->default degerdir beyaz
sns.scatterplot(x="Height", y="Weight", hue="Sex",style="Medal", size="Age", data=veriler) #her birinin stilini medal'a gore degistir
#size ise verilen parametrey gore datapointlere boyut verir. mesela burda yas'a verdik. buyuk yas'a buyuk boyut verir mesela
plt.xlabel("uzunluk")
plt.ylabel("kilo")
plt.title("uzunluk-kilo")
plt.show()

# %%
sns.set_style("darkgrid")
sns.lineplot(x="Height", y="Weight", hue="Sex", data=veriler)
plt.xlabel("uzunluk")
plt.ylabel("kilo")
plt.title("uzunluk-kilo")
plt.show()

# %% [markdown]
# #### bu da goruldugu uzere 'cizgi-grafigi' seklindedir.

# %% [markdown]
# ### Peki ya Dagilim?

# %%
sns.set_style("dark")
sns.displot(x="Height", hue="Sex", data=veriler) #displot-->distribution plot'u demek
plt.ylabel("frekans")
plt.title("atletlerin uzunluk dagilimi")
plt.show()

# %% [markdown]
# #### cizgi seklinde gostermek icin;

# %%
sns.set_style("dark")
sns.displot(x="Height", hue="Sex", data=veriler, kind="kde") #kind="kde" ekledik (kernel density estimTE)
plt.ylabel("frekans")
plt.title("atletlerin uzunluk dagilimi")
plt.show()

# %% [markdown]
# ### categorize plot

# %%
sns.catplot(x="Medal", y="Height", hue="Sex", col="Season", data=veriler)#col-->column'lari neye gore ayirt edecegiz onu soyleriz

# %%
veriler.corr(numeric_only=True) #sadece numeric datalari alarak korelasyon'a bak
# Out:
#               ID       Age    Height    Weight      Year
# ID      1.000000 -0.003631 -0.011141 -0.009176  0.011885
# Age    -0.003631  1.000000  0.138246  0.212069 -0.115137
# Height -0.011141  0.138246  1.000000  0.796213  0.047578
# Weight -0.009176  0.212069  0.796213  1.000000  0.019095
# Year    0.011885 -0.115137  0.047578  0.019095  1.000000

# %% [markdown]
# ##### tabi cok fazla veri olursa incelemek zor olucaktir bunu demi. gorsel olarak incelemek daha kolaydir yaziya gore

# %%
sns.heatmap(veriler.corr(numeric_only=True), annot=True) #corelasyon seviyesine gore renklşendirme yapiyorr;
# Out:
# <Axes: >
